# %% [markdown]
# # Object Tracking with MATA
#
# Demonstrates frame-by-frame object tracking with persistent track IDs
# displayed in the `VisionResult` auto-display table.
#
# **Model used**: `facebook/detr-resnet-50` + BotSort tracker
#
# **Prerequisites**: `pip install datamata[notebook]`

# %%
# !pip install datamata[notebook]

# %%
import mata
print(f"MATA version: {mata.__version__}")
# Out:
# MATA version: 1.9.4

# %%
# Load a tracking adapter
tracker = mata.load(
    "track",
    "torchvision/fasterrcnn_resnet50_fpn_v2",
    tracker="botsort",
    threshold=0.3,
)
# Out:
# [INFO] Loading track model from torchvision: torchvision/fasterrcnn_resnet50_fpn_v2
# [INFO] Loading torchvision detection model: torchvision/fasterrcnn_resnet50_fpn_v2
# [INFO] Auto-selected CUDA device (NVIDIA GeForce RTX 3070)
# [INFO] Initialized TorchvisionDetectAdapter with device=cuda, threshold=0.3
# [INFO] Loading torchvision model: fasterrcnn_resnet50_fpn_v2
# [INFO] Loaded with new API (weights='DEFAULT')
# [INFO] Model loaded successfully on cuda

# %%
import cv2

VIDEO = "../../data/assets/videos/cup.mp4"  # replace with your video
cap = cv2.VideoCapture(VIDEO)

results = []
for _ in range(10):  # process first 10 frames
    ret, frame = cap.read()
    if not ret:
        break
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = tracker.update(frame_rgb, persist=True)
    results.append(result)

cap.release()
print(f"Processed {len(results)} frames")
# Out:
# Processed 10 frames

# %%
# Auto-display the last frame's tracking result (includes Track ID column)
results[-1]
# Out:
# VisionResult(instances=[Instance(score=0.7565539479255676, label=77, bbox=(311.1567375243749, 116.8118215129069, 411.41760406304064, 383.71707620977077), mask=None, label_name='cell phone', area=None, is_stuff=None, embedding=None, track_id=1, keypoints=None), Instance(score=0.9341164827346802, label=1, bbox=(350.5000787011646, 172.98879571750112, 640.1199072129193, 296.0016803424646), mask=None, label_name='person', area=None, is_stuff=None, embedding=None, track_id=2, keypoints=None), Instance(score=0.9249491691589355, label=47, bbox=(307.2722542518776, 121.46216961199474, 416.056259891332, 370.4712717843128), mask=None, label_name='cup', area=None, is_stuff=None, embedding=None, track_id=3, keypoints=None)], meta={'source': 'tracking_adapter'}, text=None, prompt=None, entities=[])

# %%
# One-liner video tracking with mata.track()
results = mata.track(VIDEO, model="facebook/detr-resnet-50", tracker="botsort", conf=0.3)
results[-1]  # display last frame
# Out:
# [INFO] Loading track model from huggingface: facebook/detr-resnet-50
# [INFO] Auto-selected CUDA device (NVIDIA GeForce RTX 3070)
# [INFO] Initialized HuggingFaceDetectAdapter with device=cuda, threshold=0.3
# [INFO] Loading HuggingFace model: facebook/detr-resnet-50
# [INFO] Detected architecture: detr
# [INFO] Model loaded successfully on cuda
# VisionResult(instances=[Instance(score=0.9985941052436829, label=1, bbox=(302.0427257687046, 149.8851914976811, 639.6031868678896, 298.7451747555325), mask=None, label_name='person', area=None, is_stuff=None, embedding=None, track_id=15, keypoints=None), Instance(score=0.6788110136985779, label=44, bbox=(257.003263331331, 81.61173893992569, 378.0851698618535, 401.7295117464156), mask=None, label_name='bottle', area=None, is_stuff=None, embedding=None, track_id=14, keypoints=None)], meta={'source': 'tracking_adapter', 'frame_idx': 216}, text=None, prompt=None, entities=[])
